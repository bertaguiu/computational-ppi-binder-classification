# %% [markdown]
# # Processament dels resultats de Rosetta - BBF-14
#
# Aquest notebook analitza les estructures generades per Rosetta Relax i calcula les mètriques energètiques globals i les mètriques específiques d'interfície per als 14 complexos del dataset BBF-14.
#
# Els càlculs de Rosetta Relax proporcionen l'energia total del complex (score total en REU) però no permeten aïllar directament la contribució energètica de la interfície entre les dues cadenes. Per obtenir les mètriques d'interfície (ΔG, ΔSASA, packstat, ponts d'hidrogen, complementarietat de forma) és necessari aplicar una anàlisi addicional sobre les estructures optimitzades. Rosetta genera fitxers de sortida en format silent (.out) que contenen tota la informació estructural i energètica en format binari, de manera que no cal reenviar els PDBs originals al clúster.
#
# La funció analyseRosettaCalculation de la classe proteinModels llegeix els fitxers .out, reconstrueix les estructures mitjançant PyRosetta (executat dins l'entorn conda pp_pyro) i calcula les mètriques energètiques globals i les d'interfície per a la parella de cadenes A_B (target–binder). El resultat és un dataframe amb una fila per estructura i complex, que es guarda com a CSV per a l'agregació posterior.

# %%
import sys
from pathlib import Path
from prepare_proteins import proteinModels
import pandas as pd

# Base del projecte
base = Path.cwd().parent

models_folder = base / "Scripts" / "rosetta_relax_bbf14" / "input_models" # Carpeta on hi ha les estructures dels complexos .pdb

rosetta_folder = base / "Scripts" / "rosetta_relax_bbf14" # Carpeta on hi ha els càlculs de Rosetta

sequence_models = proteinModels(str(models_folder))

rosetta_data = sequence_models.analyseRosettaCalculation(
    rosetta_folder=str(rosetta_folder),
    interface_chains="A_B",
    pyrosetta_env="pp_pyro",
    verbose=True,
    cpus=2
)

print("\n=== ROSETTA DATA ===")
print(rosetta_data.head())

output_csv = rosetta_folder / "rosetta_data_full.csv"
rosetta_data.to_csv(output_csv)

print(f"\nData guardada a: {output_csv}")
# Out:
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# Checking calculations for model Complex8
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex8.csv was found
# 	Interface metric score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/binding_energy/Complex8.csv was found
# 	All calculations were completed for model Complex8
# Checking calculations for model Complex6
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex6.csv was found
# 	Interface metric score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/binding_energy/Complex6.csv was found
# 	All calculations were completed for model Complex6
# Checking calculations for model Complex1
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex1.csv was found
# 	Interface metric score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/binding_energy/Complex1.csv was found
# 	All calculations were completed for model Complex1
# Checking calculations for model Complex12
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex12.csv was found
# 	Interface metric score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/binding_energy/Complex12.csv was found
# 	All calculations were completed for model Complex12
# Checking calculations for model Complex13
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex13.csv was found
# 	Interface metric score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/binding_energy/Complex13.csv was found
# 	All calculations were completed for model Complex13
# Checking calculations for model Complex7
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex7.csv was found
# 	Interface metric score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/binding_energy/Complex7.csv was found
# 	All calculations were completed for model Complex7
# Checking calculations for model Complex14
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex14.csv was found
# 	Interface metric score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/binding_energy/Complex14.csv was found
# 	All calculations were completed for model Complex14
# Checking calculations for model Complex9
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex9.csv was found
# 	Interface metric score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/binding_energy/Complex9.csv was found
# 	All calculations were completed for model Complex9
# Checking calculations for model Complex2
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex2.csv was found
# 	Calculating 111 interface metric sets
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# Checking calculations for model Complex11
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex11.csv was found
# 	Calculating 111 interface metric sets
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# Checking calculations for model Complex5
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex5.csv was found
# 	Calculating 111 interface metric sets
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# Checking calculations for model Complex4
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex4.csv was found
# 	Calculating 111 interface metric sets
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# Checking calculations for model Complex10
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex10.csv was found
# 	Calculating 111 interface metric sets
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# Checking calculations for model Complex3
# 	Score file /Users/bertaguiu/projects/Scripts/rosetta_relax/.analysis/scores/Complex3.csv was found
# 	Calculating 111 interface metric sets
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.m1.cxx11thread.serialization.python311.Release 2026.06+release.1a56185c2592611dec4c9c75ddc9468cd2227c1f 2026-01-30T13:14:27] retrieved from: http://www.pyrosetta.org
#
# === ROSETTA DATA ===
#                  score    fa_atr   fa_rep   fa_sol  fa_intra_rep  \
# Model    Pose
# Complex1 1    -662.683 -1127.711  143.777  647.761         2.178
#          2    -660.587 -1125.585  146.516  626.533         2.100
#          3    -656.360 -1126.652  148.185  634.969         2.123
#          4    -651.500 -1124.470  146.215  633.848         2.218
#          5    -658.604 -1113.863  144.251  622.038         2.112
#
#                fa_intra_sol_xover4  lk_ball_wtd  fa_elec  pro_close  \
# Model    Pose
# Complex1 1                  37.085      -18.736 -380.600      0.816
#          2                  37.795      -20.599 -372.187      1.029
#          3                  36.408      -21.538 -372.869      1.000
#          4                  38.446      -20.867 -375.599      0.733
#          5                  37.087      -21.282 -372.203      1.136
#
#                hbond_sr_bb  ...  interface_score_A_B  interface_dG_A_B  \
# Model    Pose               ...
# Complex1 1         -47.423  ...           -48.609605        -48.609605
#          2         -45.758  ...           -48.711471        -48.711471
#          3         -45.667  ...           -51.088060        -51.088060
#          4         -46.657  ...           -50.626876        -50.626876
#          5         -47.877  ...           -47.170656        -47.170656
#
#                interface_delta_sasa_A_B  interface_packstat_A_B  \
# Model    Pose
# Complex1 1                  1502.052392                0.647614
#          2                  1480.578094                0.662955
#          3                  1513.804826                0.688719
#          4                  1492.246900                0.562916
#          5                  1492.818313                0.646200
#
#                interface_delta_hbond_unsat_A_B  interface_nres_A_B  \
# Model    Pose
# Complex1 1                                   4                  68
#          2                                   3                  67
#          3                                   3                  69
#          4                                   2                  68
#          5                                   4                  69
#
#                interface_hbonds_A_B  interface_sc_A_B  \
# Model    Pose
# Complex1 1                        6          0.694067
#          2                        4          0.718055
#          3                        4          0.719636
#          4                        5          0.692856
#          5                        4          0.697190
#
#                interface_dG_dSASA_ratio_A_B  interface_total_hbond_E_A_B
# Model    Pose
# Complex1 1                        -0.032362                    -5.292724
#          2                        -0.032900                    -3.463937
#          3                        -0.033748                    -3.648178
#          4                        -0.033927                    -4.308201
#          5                        -0.031598                    -3.458436
#
# [5 rows x 31 columns]
#
# Data guardada a: /Users/bertaguiu/projects/Scripts/rosetta_relax/rosetta_data_full.csv
